# %% [markdown]
# # Project Title:
#
# # Data Analysis
#
# # Task 1: Web Scraping
#
# Used BeautifulSoup and requests to extract data from a website.
#
# Scraped real-time data (news titles) from a public webpage.
#
# Parsed HTML structure and extracted relevant elements.
#
# Stored the extracted data in structured format (list → dataset).
#
# Outcome:
#
# Learned how to handle HTML structure
#
# Built custom dataset from raw web data
#
# # Task 2: Exploratory Data Analysis (EDA)
#
# Questions Asked:
#
# How many news titles are there?
#
# What is the average length of titles?
#
# Are there any long or short titles?
#
# Work Done:
#
# Created dataset using Pandas
#
# Added new feature: Title Length
#
# Analyzed patterns in text data
#
# Identified variation in title sizes
#
# Outcome:
#
# Understood data structure and patterns
#
# Performed basic statistical analysis
#
# # Task 3: Data Visualization
#
# Used Matplotlib to create visual insights
#
# Created bar chart showing title length distribution
#
# Transformed raw data into visual format
#
# Visualization Insights:
#
# Compared title lengths
#
# Identified short vs long titles easily
#
# Outcome:
#
# Converted data into meaningful visuals
#
# Improved understanding through graphs
#
# # Overall Learning
#
# Web Scraping using Python
#
# Data Cleaning & Structuring
#
# Exploratory Data Analysis (EDA)
#
# Data Visualization Techniques
#
# # Tools & Technologies
#
# Python
#
# BeautifulSoup
#
# Pandas
#
# Matplotlib
#
# Jupyter Notebook
