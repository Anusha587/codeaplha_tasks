# %%
Title,Length
GrapheneOS – Break Free from Google and Apple,49
Four Column ASCII (2017),27
14-year-old Miles Wu folded origami pattern,52
Glitchy camera – a circuit-bent simulator,48
Rise of the Triforce,22
How teaching molecules to think works,43
Rendering the Visible Spectrum,33
Deep dive into Apple car file format,40
Poor Deming never stood a chance,36
What your Bluetooth devices reveal,39
